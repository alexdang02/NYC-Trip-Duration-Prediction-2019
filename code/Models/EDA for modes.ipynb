# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/home/trungdc/unimelb/MAST30024/asm/mast30034_2021_s2_project_1-alexdang02-1/Data/Model/train1.csv")
df.head()
# Out:
#    passenger_count  trip_distance  RatecodeID  PULocationID  DOLocationID  \
# 0                1           14.0           1           100            11
# 1                1           15.0           1           100            11
# 2                4            2.0           1           107           161
# 3                1            1.0           1           107           161
# 4                1            1.0           1           107           161
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  ...   cdd  \
# 0             2         47.0    0.0      0.5        0.00  ...  11.7
# 1             1         45.5    0.5      0.5        9.36  ...  16.5
# 2             1         10.0    0.5      0.5        3.39  ...   0.0
# 3             2          8.5    0.0      0.5        0.00  ...   0.0
# 4             2          7.5    0.0      0.5        0.00  ...   0.0
#
#    precipitation  newSnow  snowDepth  DayofWeek  Weekend  Month  Hour  \
# 0            0.6      0.0        0.0          4        0      7    13
# 1            0.1      0.0        0.0          4        0      8    22
# 2            0.0      0.0        0.0          2        0      1     3
# 3            0.0      0.0        0.0          2        0      1    10
# 4            0.0      0.0        0.0          2        0      1    11
#
#    WorkingHour   Key
# 0            1  4,13
# 1            0  4,22
# 2            0   2,3
# 3            1  2,10
# 4            1  2,11
#
# [5 rows x 29 columns]

# %%
plt.hist(df["duration"], bins= 50)
# Out:
# (array([1.243685e+06, 9.682900e+05, 3.571820e+05, 1.324650e+05,
#         5.576900e+04, 2.694700e+04, 1.311800e+04, 6.266000e+03,
#         2.852000e+03, 1.220000e+03, 4.450000e+02, 1.980000e+02,
#         1.020000e+02, 8.000000e+01, 5.100000e+01, 2.300000e+01,
#         1.000000e+01, 2.000000e+01, 1.500000e+01, 1.400000e+01,
#         1.200000e+01, 7.000000e+00, 8.000000e+00, 1.100000e+01,
#         9.000000e+00, 5.000000e+00, 4.000000e+00, 8.000000e+00,
#         6.000000e+00, 4.000000e+00, 8.000000e+00, 3.000000e+00,
#         4.000000e+00, 3.000000e+00, 4.000000e+00, 7.000000e+00,
#         6.000000e+00, 8.000000e+00, 8.000000e+00, 7.000000e+00,
#         8.000000e+00, 6.000000e+00, 5.000000e+00, 6.000000e+00,
#         4.000000e+00, 6.000000e+00, 5.000000e+00, 4.000000e+00,
#         4.000000e+00, 6.000000e+00]),
#  array([  1.  ,  10.92,  20.84,  30.76,  40.68,  50.6 ,  60.52,  70.44,
#          80.36,  90.28, 100.2 , 110.12, 120.04, 129.96, 139.88, 149.8 ,
#         159.72, 169.64, 179.56, 189.48, 199.4 , 209.32, 219.24, 229.16,
#         239.08, 249.  , 258.92, 268.84, 278.76, 288.68, 298.6 , 308.52,
#         318.44, 328.36, 338.28, 348.2 , 358.12, 368.04, 377.96, 387.88,
#         397.8 , 407.72, 417.64, 427.56, 437.48, 447.4 , 457.32, 467.24,
#         477.16, 487.08, 497.  ]),
#  <BarContainer object of 50 artists>)
